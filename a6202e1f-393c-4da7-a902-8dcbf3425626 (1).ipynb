# %%
l1=[1,2,3,4,5,6,7]
l2=("nono")
l3=["momo",25,"nono",23,"dodo",15]
l4=list([12,14,16])
l5=list("momo")
l6= l1 + l3
print (l1[0:3])
print (l2[:4])
print (l3[2:])
print ("nono" not in l2)
print (l6)
print (len(l1), max(l1), min(l1),sum(l1))
# Out:
# [1, 2, 3]
# nono
# ['nono', 23, 'dodo', 15]
# False
# [1, 2, 3, 4, 5, 6, 7, 'momo', 25, 'nono', 23, 'dodo', 15]
# 7 7 1 28

# %%
l1=[1,2,3,4,5,6,7]
l1.append(60)
print(l1)
l1.extend([70,80,90,70])
print(l1)
print(l1.count(70))
print(l1.index(5))
l1.reverse()
print(l1)
print(l1.pop(5))
l1.remove(70)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 60]
# [1, 2, 3, 4, 5, 6, 7, 60, 70, 80, 90, 70]
# 2
# 4
# [70, 90, 80, 70, 60, 7, 6, 5, 4, 3, 2, 1]
# 7
# [90, 80, 70, 60, 6, 5, 4, 3, 2, 1]

# %%
person=[["nono","koko","lolo"],[15,16,17],["aosh",25,"keta"]]
name= person[0]
#print (name)
print (person[0][1])
# Out:
# koko

# %%
t1= (10,20,30);
t2= tuple([50,60,70])
t3= tuple();
t4=tuple("python");
print (t1,t2,t3,t4)
print (t4[2:])
print (max(t1),min(t1),len(t1),sum(t1))
print (50 not in t1)
t7=((3,7,9),("nono"),(2,4,6))
print (t7[0])
print (t7[0][2])
# Out:
# (10, 20, 30) (50, 60, 70) () ('p', 'y', 't', 'h', 'o', 'n')
# ('t', 'h', 'o', 'n')
# 30 10 3 60
# True
# (3, 7, 9)
# 9

# %%
t1= (10,20,30)
for i in t1:
       print (i,end="\n");
# Out:
# 10
# 20
# 30

# %%
friends ={"mody": 30 , "dody" :40 ,"hoda" :55 }
print (friends)
# Out:
# {'mody': 30, 'dody': 40, 'hoda': 55}

# %%
countries={}
countries["egypt"] =100
countries["usa"] =200
countries["saudia"] =25
print(countries) 
countries ["egypt"]=150
print(countries) 
print(countries.keys()) 
print(countries.values())
del (countries["usa"])
print(countries.keys())
print (len(countries))
print ("usa" not in countries)
# Out:
# {'egypt': 100, 'usa': 200, 'saudia': 25}
# {'egypt': 150, 'usa': 200, 'saudia': 25}
# dict_keys(['egypt', 'usa', 'saudia'])
# dict_values([150, 200, 25])
# dict_keys(['egypt', 'saudia'])
# 2
# True

# %%
d1 ={"mody": 30 , "dody" :40 ,"hoda" :55 }
#d1 ={"mark":25,"nody":50}
d2 ={"mark":25,"nody":50}
print (d1==d2)
# Out:
# False

# %%
countries["egypt"] =100
countries["usa"] =200
countries["saudia"] =25
#print(countries)
#countries.popitem()
#print(countries)
#countries.pop("egypt")
#print(countries)
#print(countries.get("egypt"))
#print(countries.get("anything", "not exist"))
#print(countries("anything", "not exist"))
#for k in countries:
       #print (k,countries[i],end="\n");
#for k in countries.values():
    #print(k)
countries.clear()
print(countries)
# Out:
# {}

# %%
print (15<14)
print (15>14)
print (15!=15)
# Out:
# False
# True
# False

# %%
#no = int(input("put it"))

coinN= int(input("Enter next coin: "))

    # if coinN == "" and totalcoin == rand: 
        # print("Congratulations. Your calculations were a success.")
    # if coinN == "" and totalcoin < rand:
       #  print("I'm sorry. You only entered",totalcoin,"cents.")  

 #except ValueError:
    # print("Invalid Input")
# else:
     totalcoin = totalcoin + coinN

# %%
no = int(input("Enter next coin: "))
if no %2 == 0 :
    print ("Even Number")
else :
    print("Odd Nuber")
